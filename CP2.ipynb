# %% [markdown]
# <a href="https://colab.research.google.com/github/patrickpais/SERS-CP2/blob/main/CP2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **PRIMEIRO EXERCICIO CP2**
#
# Vamos treinar um modelo preditivo de Machine Learning para
# classificar a estabilidade da rede elétrica.
#
# 1 atributo alvo (target) -----> array com referência à coluna 'stabf'
# Classes: 'stable' e 'unstable'
# Criar uma variável chamada y com os dados da coluna 'stabf'
#
# 13 atributos numéricos ------> 12 serão usados como Features para o modelo.
# Criar um dataframe com esses 12 atributos e chamar de X.

# %%
from os import set_inheritable
#PREPARAÇÃO DE AMBIENTE

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#ALGORITMO DE REGRASSÃO LOGÍSTICA ---> ALGORITMO DE CLASSIFICAÇÃO
from sklearn.linear_model import LogisticRegression

#SEPARAÇÃO DOS DADOS DE TREINO E DE TESTE
#No exemplo, usaremos 20% para teste e 80% para treino
#x_train, x_test, y_train, y_test (y coluna stabf e x data frame com 12 atributos)
from sklearn.model_selection import train_test_split

#Métricas de avaliação para classificação
from sklearn.metrics import accuracy_score

# %% [markdown]
# Criação do dataframe 'dados'

# %%
dados = pd.read_csv('https://raw.githubusercontent.com/patrickpais/SERS-CP2/refs/heads/main/Data_for_UCI_named.csv')

dados.head()
# Out:
#        tau1      tau2      tau3      tau4        p1        p2        p3  \
# 0  2.959060  3.079885  8.381025  9.780754  3.763085 -0.782604 -1.257395
# 1  9.304097  4.902524  3.047541  1.369357  5.067812 -1.940058 -1.872742
# 2  8.971707  8.848428  3.046479  1.214518  3.405158 -1.207456 -1.277210
# 3  0.716415  7.669600  4.486641  2.340563  3.963791 -1.027473 -1.938944
# 4  3.134112  7.608772  4.943759  9.857573  3.525811 -1.125531 -1.845975
#
#          p4        g1        g2        g3        g4      stab     stabf
# 0 -1.723086  0.650456  0.859578  0.887445  0.958034  0.055347  unstable
# 1 -1.255012  0.413441  0.862414  0.562139  0.781760 -0.005957    stable
# 2 -0.920492  0.163041  0.766689  0.839444  0.109853  0.003471  unstable
# 3 -0.997374  0.446209  0.976744  0.929381  0.362718  0.028871  unstable
# 4 -0.554305  0.797110  0.455450  0.656947  0.820923  0.049860  unstable

# %%
#Inspeção inicial

dados.shape
# Out:
# (10000, 14)

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   tau1    10000 non-null  float64
#  1   tau2    10000 non-null  float64
#  2   tau3    10000 non-null  float64
#  3   tau4    10000 non-null  float64
#  4   p1      10000 non-null  float64
#  5   p2      10000 non-null  float64
#  6   p3      10000 non-null  float64
#  7   p4      10000 non-null  float64
#  8   g1      10000 non-null  float64
#  9   g2      10000 non-null  float64
#  10  g3      10000 non-null  float64
#  11  g4      10000 non-null  float64
#  12  stab    10000 non-null  float64
#  13  stabf   10000 non-null  object
# dtypes: float64(13), object(1)
# memory usage: 1.1+ MB

# %%
#Atributos com valores numéricos
dados.describe()
# Out:
#                tau1          tau2          tau3          tau4            p1  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean       5.250000      5.250001      5.250004      5.249997      3.750000
# std        2.742548      2.742549      2.742549      2.742556      0.752160
# min        0.500793      0.500141      0.500788      0.500473      1.582590
# 25%        2.874892      2.875140      2.875522      2.874950      3.218300
# 50%        5.250004      5.249981      5.249979      5.249734      3.751025
# 75%        7.624690      7.624893      7.624948      7.624838      4.282420
# max        9.999469      9.999837      9.999450      9.999443      5.864418
#
#                  p2            p3            p4            g1            g2  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean      -1.250000     -1.250000     -1.250000      0.525000      0.525000
# std        0.433035      0.433035      0.433035      0.274256      0.274255
# min       -1.999891     -1.999945     -1.999926      0.050009      0.050053
# 25%       -1.624901     -1.625025     -1.624960      0.287521      0.287552
# 50%       -1.249966     -1.249974     -1.250007      0.525009      0.525003
# 75%       -0.874977     -0.875043     -0.875065      0.762435      0.762490
# max       -0.500108     -0.500072     -0.500025      0.999937      0.999944
#
#                  g3            g4          stab
# count  10000.000000  10000.000000  10000.000000
# mean       0.525000      0.525000      0.015731
# std        0.274255      0.274255      0.036919
# min        0.050054      0.050028     -0.080760
# 25%        0.287514      0.287494     -0.015557
# 50%        0.525015      0.525002      0.017142
# 75%        0.762440      0.762433      0.044878
# max        0.999982      0.999930      0.109403

# %%
#Atributos com valores categóricos
dados.describe(include='object')
# Out:
#            stabf
# count      10000
# unique         2
# top     unstable
# freq        6380

# %%
#Renomeando os labels
dados['stabf'] = dados['stabf'].map({'unstable':'INSTÁVEL', 'stable':'ESTÁVEL'})
dados.head()
# Out:
#        tau1      tau2      tau3      tau4        p1        p2        p3  \
# 0  2.959060  3.079885  8.381025  9.780754  3.763085 -0.782604 -1.257395
# 1  9.304097  4.902524  3.047541  1.369357  5.067812 -1.940058 -1.872742
# 2  8.971707  8.848428  3.046479  1.214518  3.405158 -1.207456 -1.277210
# 3  0.716415  7.669600  4.486641  2.340563  3.963791 -1.027473 -1.938944
# 4  3.134112  7.608772  4.943759  9.857573  3.525811 -1.125531 -1.845975
#
#          p4        g1        g2        g3        g4      stab     stabf
# 0 -1.723086  0.650456  0.859578  0.887445  0.958034  0.055347  INSTÁVEL
# 1 -1.255012  0.413441  0.862414  0.562139  0.781760 -0.005957   ESTÁVEL
# 2 -0.920492  0.163041  0.766689  0.839444  0.109853  0.003471  INSTÁVEL
# 3 -0.997374  0.446209  0.976744  0.929381  0.362718  0.028871  INSTÁVEL
# 4 -0.554305  0.797110  0.455450  0.656947  0.820923  0.049860  INSTÁVEL

# %%
#Quais classes temos na coluna'stabf' (target)?
dados['stabf'].unique()
# Out:
# array(['INSTÁVEL', 'ESTÁVEL'], dtype=object)

# %%
#Quantos registros temos de cada classe?
dados['stabf'].value_counts()
# Out:
# stabf
# INSTÁVEL    6380
# ESTÁVEL     3620
# Name: count, dtype: int64

# %%
dados.columns
# Out:
# Index(['tau1', 'tau2', 'tau3', 'tau4', 'p1', 'p2', 'p3', 'p4', 'g1', 'g2',
#        'g3', 'g4', 'stab', 'stabf'],
#       dtype='object')

# %%
#Features -> Variáveis de entrada para o modelo -> variáveis independentes
#X -> dataframe com as 12 primeiras colunas

x = dados.drop(['stab', 'stabf'], axis=1)
x.head()
# Out:
#        tau1      tau2      tau3      tau4        p1        p2        p3  \
# 0  2.959060  3.079885  8.381025  9.780754  3.763085 -0.782604 -1.257395
# 1  9.304097  4.902524  3.047541  1.369357  5.067812 -1.940058 -1.872742
# 2  8.971707  8.848428  3.046479  1.214518  3.405158 -1.207456 -1.277210
# 3  0.716415  7.669600  4.486641  2.340563  3.963791 -1.027473 -1.938944
# 4  3.134112  7.608772  4.943759  9.857573  3.525811 -1.125531 -1.845975
#
#          p4        g1        g2        g3        g4
# 0 -1.723086  0.650456  0.859578  0.887445  0.958034
# 1 -1.255012  0.413441  0.862414  0.562139  0.781760
# 2 -0.920492  0.163041  0.766689  0.839444  0.109853
# 3 -0.997374  0.446209  0.976744  0.929381  0.362718
# 4 -0.554305  0.797110  0.455450  0.656947  0.820923

# %%
# Target -> variável alvo -> variável dependente
# array y com dados da conuna 'stabf'
y = dados['stabf']
y
# Out:
# 0       INSTÁVEL
# 1        ESTÁVEL
# 2       INSTÁVEL
# 3       INSTÁVEL
# 4       INSTÁVEL
#           ...
# 9995    INSTÁVEL
# 9996     ESTÁVEL
# 9997     ESTÁVEL
# 9998    INSTÁVEL
# 9999    INSTÁVEL
# Name: stabf, Length: 10000, dtype: object

# %%
# Separando dados para treino e para teste
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
# Treinar modelo com base no algoritmo LogisticRegression
model = LogisticRegression()
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
# Probabilidades das previsões
probabilidades = model.predict_proba(x_test)
probabilidades[:30]
# Out:
# array([[0.04609348, 0.95390652],
#        [0.06082634, 0.93917366],
#        [0.31665189, 0.68334811],
#        [0.97845447, 0.02154553],
#        [0.64488737, 0.35511263],
#        [0.57310264, 0.42689736],
#        [0.7293308 , 0.2706692 ],
#        [0.0220369 , 0.9779631 ],
#        [0.04455238, 0.95544762],
#        [0.74263825, 0.25736175],
#        [0.05821672, 0.94178328],
#        [0.43539611, 0.56460389],
#        [0.54821046, 0.45178954],
#        [0.22628137, 0.77371863],
#        [0.01738045, 0.98261955],
#        [0.24059749, 0.75940251],
#        [0.43383254, 0.56616746],
#        [0.19235057, 0.80764943],
#        [0.42956875, 0.57043125],
#        [0.30915071, 0.69084929],
#        [0.08327983, 0.91672017],
#        [0.1285647 , 0.8714353 ],
#        [0.19005429, 0.80994571],
#        [0.77021981, 0.22978019],
#        [0.34514059, 0.65485941],
#        [0.29155465, 0.70844535],
#        [0.61401301, 0.38598699],
#        [0.48196263, 0.51803737],
#        [0.69575885, 0.30424115],
#        [0.92903344, 0.07096656]])

# %%
# Gerando o array com as previsões
y_predict = model.predict(x_test)
y_predict[:30]
# Out:
# array(['INSTÁVEL', 'INSTÁVEL', 'INSTÁVEL', 'ESTÁVEL', 'ESTÁVEL',
#        'ESTÁVEL', 'ESTÁVEL', 'INSTÁVEL', 'INSTÁVEL', 'ESTÁVEL',
#        'INSTÁVEL', 'INSTÁVEL', 'ESTÁVEL', 'INSTÁVEL', 'INSTÁVEL',
#        'INSTÁVEL', 'INSTÁVEL', 'INSTÁVEL', 'INSTÁVEL', 'INSTÁVEL',
#        'INSTÁVEL', 'INSTÁVEL', 'INSTÁVEL', 'ESTÁVEL', 'INSTÁVEL',
#        'INSTÁVEL', 'ESTÁVEL', 'INSTÁVEL', 'ESTÁVEL', 'ESTÁVEL'],
#       dtype=object)

# %%
# Métrica de avaliação
acuracia = accuracy_score(y_test, y_predict)
acuracia
# Out:
# 0.817
